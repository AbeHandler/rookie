# %%
# %matplotlib inline

from elasticsearch import Elasticsearch
from rookie.utils import query_elasticsearch
from rookie.classes import Result

import collections

c = collections.Counter()

es = Elasticsearch()

results = query_elasticsearch("Landrieu")
# Out:
# INFO:rookie:querying elastic search
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-390135f0caaf> in <module>()
#      11 es = Elasticsearch()
#      12
# ---> 13 results = query_elasticsearch("Landrieu")
#
# /Users/abramhandler/research/rookie/rookie/utils.py in query_elasticsearch(lucene_query)
#      95     entity_dict = {}
#      96     for key in keys:
# ---> 97         entity_dict[key] = get_entity_counts(entities, key, results)
#      98     words = get_word_counts(results)
#      99     results = [Result(r) for r in results]
#
# /Users/abramhandler/research/rookie/rookie/utils.py in get_entity_counts(entities, etype, results)
#      69             collections.Counter(entities[etype]).most_common(25)]
#      70     for e in ents:
# ---> 71         e.timestamps = get_timestamps(e.name, etype, results)
#      72     return ents
#      73
#
# NameError: global name 'p' is not defined

# %%
import random
import datetime
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.dates as mdates

def plot(array_of_timestamps, name):
    array = [a.toordinal() for a in array_of_timestamps]
    mpl_data = np.array(array)
    mdates.DateFormatter('%Y-%m-%d')

    # plot it
    fig, ax = plt.subplots(1,1)
    ax.hist(mpl_data, bins=15, color='lightblue')
    ax.xaxis.set_major_locator(mdates.YearLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%d.%m.%y'))
    plt.title(name)
    plt.show()

for person in results.organizations:
    hits = []
    for r in results.results:
        if person.name in r.entities['ORGANIZATION']:
            hits.append(r.timestamp)
    plot(hits, person.name)
